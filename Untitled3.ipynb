# %% [markdown]
# <a href="https://colab.research.google.com/github/RezkiFadhillah/RezkiFadhillah-2170231007-PemrogramanWeb/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#library untuk lvisualisasi
import matplotlib.pyplot as plt
import seaborn as sns

#library untuk analisis time series
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# library yang digunakan untuk forecasting
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
df = pd.read_excel('CO2 dataset.xlsx')

# %%
df.head()
# Out:
#    Year      CO2
# 0  1800  0.00568
# 1  1801  0.00561
# 2  1802  0.00555
# 3  1803  0.00548
# 4  1804  0.00542

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    215 non-null    int64
#  1   CO2     215 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.5 KB

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# %%
df.set_index(['Year'], inplace=True)

# %%
df.head()
# Out:
#                 CO2
# Year
# 1800-01-01  0.00568
# 1801-01-01  0.00561
# 1802-01-01  0.00555
# 1803-01-01  0.00548
# 1804-01-01  0.00542

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('1800-01-01 00:00:00'), Timestamp('2014-01-01 00:00:00'))

# %%
if (df.index.max()- df.index.min() == 214):
  print ('Data is Continous')

# %%
df.index.freq = 'YS'

# %%
df.plot(grid=True)
# Out:
# <Axes: xlabel='Year'>

# %%
train_df = df.loc[:'1991-01-01']
test_df = df.loc['1992-01-01':]

# %%
decompose_add = seasonal_decompose(df['CO2'])
decompose_add.plot()

# %%
def adf_test(timeseries):
  print ('Hasil testing Dickey-Fuller')
  print('--------------------------')
  adftest = adfuller(timeseries)
  adf_output = pd.Series(adftest[0:4], index=['Test statistic','p-value','Lags Used','Number of Observation Used'])
  for key, Value in adftest[4].items() :
    adf_output['Critical Value (%s)' %key] = Value
  print (adf_output)

adf_test(df.values)
# Out:
# Hasil testing Dickey-Fuller
# --------------------------
# Test statistic                 -0.378463
# p-value                         0.913633
# Lags Used                       0.000000
# Number of Observation Used    214.000000
# Critical Value (1%)            -3.461282
# Critical Value (5%)            -2.875143
# Critical Value (10%)           -2.574020
# dtype: float64

# %%
adf_test(df.values)
# Out:
# Hasil testing Dickey-Fuller
# --------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6d9198fdd1ea> in <cell line: 1>()
# ----> 1 adf_test(df.values)
#
# <ipython-input-23-735aedef3024> in adf_test(timeseries)
#       3   print('--------------------------')
#       4   adfest = adfuller(timeseries)
# ----> 5   adf_output = pd.Series(adftest[0:4], index=['Test statistic','p-value','Lags Used','Number of Observation Used'])
#       6   for key, Value in adftest[4].items() :
#       7     adf_output['Critical Value (%s)' %key] = Value
#
# NameError: name 'adftest' is not defined

# %%
diff_df = df.diff()
diff_df.head()
# Out:
#                 CO2
# Year
# 1800-01-01      NaN
# 1801-01-01 -0.00007
# 1802-01-01 -0.00006
# 1803-01-01 -0.00007
# 1804-01-01 -0.00006

# %%
diff_df.dropna(inplace=True)

# %%
diff_df.plot(grid=True)
# Out:
# <Axes: xlabel='Year'>

# %%
adf_test(diff_df)
# Out:
# Hasil testing Dickey-Fuller
# --------------------------
# Test statistic                 -3.780005
# p-value                         0.003119
# Lags Used                      15.000000
# Number of Observation Used    198.000000
# Critical Value (1%)            -3.463815
# Critical Value (5%)            -2.876251
# Critical Value (10%)           -2.574611
# dtype: float64

# %%
plot_acf(diff_df)
plot_pacf(diff_df)

# %%
single_exp = SimpleExpSmoothing(train_df).fit()
single_exp_train_pred = single_exp.fittedvalues
single_exp_test_pred = single_exp.forecast(23)

# %%
train_df['CO2'].plot(style='--', color='gray', legend=True, label='train_df')
test_dff['CO2'].plot(style='--', color='r', legend=True, )
